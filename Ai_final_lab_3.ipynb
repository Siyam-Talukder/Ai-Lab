# %%
f = open("graph.txt","w")
f.write("6 9"+"\n")
f.write("0 1"+"\n")
f.write("0 2"+"\n")
f.write("1 2"+"\n")
f.write("1 3"+"\n")
f.write("2 3"+"\n")
f.write("3 4"+"\n")
f.write("4 0"+"\n")
f.write("4 1"+"\n")
f.write("4 5"+"\n")
f.close()

# %%
def createList(n):
    m={}
    for i in range(n):
        m[i]=[]
    return m

def printGraph(g):
    for k,v in g.items():
        print (k,v)

def findDegree(g,ver):
    deg = 0;
    for key,val in g.items():
        if(key==ver):
            print(len(val))
        
    

f = open("graph.txt","r")
vertex_edges = f.readline()
n_m = vertex_edges.split()
n = int(n_m[0])
m = int(n_m[1])

G = createList(n)

for i in range(m):
    line = f.readline()
    u_v = line.split()
    u = int(u_v[0])
    v = int(u_v[1])
    G[u].append(v)
    G[v].append(u)

f.close()

#printGraph(G)
findDegree(G,0)
# Out:
# 3

# %%
def createList(n):
    m={}
    for i in range(n):
        m[i]=[]
    return m

def printGraph(g):
    for k,v in g.items():
        print (k,v)

def findOutDegree(g,ver):
    for key,val in g.items():
        if(key==ver):
            print(len(val))

def findInDegree(g,ver):
    cnt=0;
    for key,val in g.items():
        for node in val:
            if(node==ver):
                cnt=cnt+1;
    print(cnt)
                

f = open("graph.txt","r")
vertex_edges = f.readline()
n_m = vertex_edges.split()
n = int(n_m[0])
m = int(n_m[1])

G = createList(n)

for i in range(m):
    line = f.readline()
    u_v = line.split()
    u = int(u_v[0])
    v = int(u_v[1])
    G[u].append(v)

f.close()

printGraph(G)
findOutDegree(G,0)
findInDegree(G,0)
# Out:
# 0 [1, 2]
# 1 [2, 3]
# 2 [3]
# 3 [4]
# 4 [0, 1, 5]
# 5 []
# 2
# 1
